# %%
from sympy import *
init_printing()
import matplotlib.pyplot as plt
import matplotlib

#from matplotlib import rcParams
#rcParams['font.family'] = 'GOST Type B'
#rcParams['font.serif'] = 'GOST Type B'

# %%
def radians(i):
    return i / 360 * 2 * pi.n(8)

def degrees(i):
    return i / (2 * pi.n(9)) * 360

h = 0.016
alpha = 24
delta = 330
rho = 0.21
omega_1 = 12.566
phi_p = delta / Rational(7, 4)
v_1, v_2 = symbols('v_1, v_2')
phi = symbols('varphi')
a1 = radians(phi_p / 4) * v_1 + v_1 * radians(phi_p / 2)
a2 = radians(phi_p / 8) * v_2 + v_2 * radians(phi_p / 4)
s1 = solve([a1 - a2, a1 - h], [v_1, v_2])
var1 = [0, (phi_p / 4).n(5), (3 * phi_p / 4).n(5), phi_p, 1.25 * phi_p.n(5), 1.375 * phi_p.n(5), 1.625 * phi_p.n(5), delta]
var1 = [radians(i) for i in var1]
var2 = [0, s1[v_1], s1[v_1], 0, 0, -s1[v_2], -s1[v_2], 0]

# %%
#from matplotlib import rcParams
#rcParams
#rcParams['font.family'] = 'GOST2304_TypeB_italic'
#rcParams['font.serif'] = 'GOST2304 Type B Italic'
#rcParams['font.serif'] = 'GOST2304 Type B Italic'

#font = {'family' : 'GOST2304 Type B-italic',
#        'weight' : 'normal',
#        'size'   : 20}

#matplotlib.rc('font', **font)

# %%
import matplotlib.font_manager as fm
new_font = fm.FontProperties(fname = 'C:\\Users\\Андрей\\Desktop\\GOST_B_.ttf')

# %%
dir(new_font)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_family',
#  '_file',
#  '_parse_fontconfig_pattern',
#  '_size',
#  '_slant',
#  '_stretch',
#  '_variant',
#  '_weight',
#  'copy',
#  'get_family',
#  'get_file',
#  'get_fontconfig_pattern',
#  'get_name',
#  'get_size',
#  'get_size_in_points',
#  'get_slant',
#  'get_stretch',
#  'get_style',
#  'get_variant',
#  'get_weight',
#  'set_family',
#  'set_file',
#  'set_fontconfig_pattern',
#  'set_name',
#  'set_size',
#  'set_slant',
#  'set_stretch',
#  'set_style',
#  'set_variant',
#  'set_weight']

# %%
new_font.get_slant()
# Out:
# 'normal'

# %%
var1 = [0, (phi_p / 4).n(5), (3 * phi_p / 4).n(5), phi_p, 1.25 * phi_p.n(5), 1.375 * phi_p.n(5), 1.625 * phi_p.n(5), delta]
var1 = [radians(i) for i in var1]
var2 = [0, s1[v_1], s1[v_1], 0, 0, -s1[v_2], -s1[v_2], 0]


fig_01 = plt.figure(figsize = [18.00, 16.00])
plt.plot(var1, var2, linewidth = 2, color = 'black')
plt.grid(True)
for obj in fig_01.findobj(matplotlib.text.Text):
    obj.set_fontproperties(new_font)
    obj.set_fontsize(40)
plt.show()

# %%
from matplotlib.backends.backend_pdf import PdfPages


plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = new_font.get_family()

with PdfPages('test.pdf') as pdf:
    
    fig_01.savefig('pic/test.pdf')
